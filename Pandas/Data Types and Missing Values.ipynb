# %% [markdown]
# # Dtypes
# The data type for a column in a DataFrame or a Series is known as the dtype.
# Data types tell us something about how pandas is storing the data internally. float64 means that it's using a 64-bit floating point number; int64 means a similarly sized integer instead, and so on.
#
# One peculiarity to keep in mind (and on display very clearly here) is that columns consisting entirely of strings do not get their own type; they are instead given the object type.
#
# It's possible to convert a column of one type into another wherever such a conversion makes sense by using the astype() function.

# %%
import pandas as pd
reviews = pd.read_csv('winemag1.csv', index_col = 0)
pd.set_option('display.max_rows', 5)

# %%
reviews.points.dtype # for a single item dtype is used
# Out:
# dtype('int64')

# %%
reviews.dtypes # to check the type of all index colunm dtypes is used
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 13, dtype: object

# %%
reviews.points.astype('float32')
# Out:
# id
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float32

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Missing data
# Entries missing values are given the value NaN(Not a Number), NaN values are a,wats of the float64 dtype.

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# id
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# id
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# id
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %%
reviews.dropna(axis = 0)
# Out:
#        country                                        description  \
# id
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# ...        ...                                                ...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
#
#                                designation  points  price    province  \
# id
# 4       Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                          Mountain Cuvée      87   19.0  California
# ...                                    ...     ...    ...         ...
# 129949                    Barrel Fermented      90   35.0  California
# 129950                       Blocks 7 & 22      90   35.0  California
#
#                  region_1           region_2     taster_name  \
# id
# 4       Willamette Valley  Willamette Valley    Paul Gregutt
# ...

# %%
modified = reviews.dropna(axis = 0)
modified
# Out:
#        country                                        description  \
# id
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# ...        ...                                                ...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
#
#                                designation  points  price    province  \
# id
# 4       Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                          Mountain Cuvée      87   19.0  California
# ...                                    ...     ...    ...         ...
# 129949                    Barrel Fermented      90   35.0  California
# 129950                       Blocks 7 & 22      90   35.0  California
#
#                  region_1           region_2     taster_name  \
# id
# 4       Willamette Valley  Willamette Valley    Paul Gregutt
# ...

# %%
new_modified = reviews.dropna(axis = 0).province.replace('Oregon', 'Kathmandu')

# %%
new_modified
# Out:
# id
# 4          Kathmandu
# 10        California
#              ...
# 129949    California
# 129950    California
# Name: province, Length: 22387, dtype: object
