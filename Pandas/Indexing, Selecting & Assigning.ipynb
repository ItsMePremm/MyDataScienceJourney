# %% [markdown]
# # Introduction

# %% [markdown]
# Selecting specific values of a pandas DataFrame or Series to work on is an implicit step in almost any data operation you'll run, so one of the first things you need to learn in working with data in Python is how to go about selecting the data points relevant to you quickly and effectively.
#
# ### Native Accessors
# Native Python objects porvide a good way of indexing data. Pandas caries all these over, which helps make it easy to start with.

# %%
import pandas as pd

# %%
winemag = pd.read_csv("winemag1.csv", index_col = 0)
pd.set_option('display.max_rows', 5)
winemag
# Out:
#          country                                        description  \
# id
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# id
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# id
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1           NaN      NaN     Roger Voss            @vossroger
# ...         ...      ...            ...                   ...
# 129969   Alsace      NaN     Roger Voss            @vossroger
# 129970   Alsace      NaN     Roger Voss            @vossroger
#
#                                                     title         variety  \
# id
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                   ...             ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# id
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
# [129971 rows x 13 columns]

# %%
winemag.province
# Out:
# id
# 0         Sicily & Sardinia
# 1                     Douro
#                 ...
# 129969               Alsace
# 129970               Alsace
# Name: province, Length: 129971, dtype: object

# %% [markdown]
# ### Indexing
# The indexing operator and attribute selection are nice because they work just like they do in the rest of the Python ecosystem. As a novice, this makes them easy to pick up and use. However, pandas has its own accessor operators, loc and iloc. For more advanced operations, these are the ones you're supposed to be using.
# #### Index-based selection
# - selecting data based on its numerical position in the data. iloc follows this paradigm.
# #### Lable-Based Selection
# - followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %%
winemag.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
winemag.iloc[0:5, 0:5]
# Out:
#      country                                        description  \
# id
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         US  Much like the regular bottling from 2012, this...
#
#                            designation  points  price
# id
# 0                         Vulkà Bianco      87    NaN
# 1                             Avidagos      87   15.0
# 2                                  NaN      87   14.0
# 3                 Reserve Late Harvest      87   13.0
# 4   Vintner's Reserve Wild Child Block      87   65.0

# %%
winemag.iloc[-5]
# Out:
# country                                                  Germany
# description    Notes of honeysuckle and cantaloupe sweeten th...
#                                      ...
# variety                                                 Riesling
# winery                  Dr. H. Thanisch (Erben Müller-Burggraef)
# Name: 129966, Length: 13, dtype: object

# %%
winemag.iloc[-4:, -3]
# Out:
# id
# 129967                    Citation 2004 Pinot Noir (Oregon)
# 129968    Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969        Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970    Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
# Name: title, dtype: object

# %%
winemag.iloc[-4:, -3:]
# Out:
#                                                     title         variety  \
# id
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                       winery
# id
# 129967              Citation
# 129968       Domaine Gresser
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit

# %%
winemag.loc[:, ['variety', 'price', 'winery']]
# Out:
#                variety  price                winery
# id
# 0          White Blend    NaN               Nicosia
# 1       Portuguese Red   15.0   Quinta dos Avidagos
# ...                ...    ...                   ...
# 129969      Pinot Gris   32.0  Domaine Marcel Deiss
# 129970  Gewürztraminer   21.0      Domaine Schoffit
#
# [129971 rows x 3 columns]

# %% [markdown]
# ### Choosing between iloc and loc:
# - When choosing between loc and iloc, note they use slightly different indexing schemes.
# - iloc follows Python's indexing scheme (inclusive start, exclusive end).
# - loc indexes inclusively, which can affect how ranges are selected.
# - loc is more convenient when dealing with non-numeric index values like strings.
# - In cases of numeric indexes, be cautious: iloc[0:1000] returns 1000 entries, while loc[0:1000] returns 1001.
# - To get 1000 elements with loc, request loc[0:999].
# - Otherwise, the usage semantics of loc are similar to iloc.
#
#
# ### Manipulating the index
# Label-based selection derives its power from the labels in the index. Critically, the index we use is not immutable. We can manipulate the index in any way we see fit.
#
# ### Conditional selection
# Conditional selection in Pandas allows you to filter rows of a DataFrame based on specific conditions. You can create boolean masks using logical operators (such as ==, >, <, etc.) to identify rows that meet certain criteria. Then, you can use these boolean masks inside the .loc[] accessor to select the rows that satisfy your conditions. This powerful feature enables you to extract, analyze, and manipulate data efficiently based on various criteria.
#
# ### Assigning
# In Pandas, assigning values to specific rows or columns within a DataFrame is straightforward and flexible. You can assign values to entire columns, specific rows, or even specific locations using various methods like .loc[], .iloc[], or direct assignment.

# %%
winemag.set_index('variety')
# Out:
#                  country                                        description  \
# variety
# White Blend        Italy  Aromas include tropical fruit, broom, brimston...
# Portuguese Red  Portugal  This is ripe and fruity, a wine that is smooth...
# ...                  ...                                                ...
# Pinot Gris        France  A dry style of Pinot Gris, this is crisp with ...
# Gewürztraminer    France  Big, rich and off-dry, this is powered by inte...
#
#                                   designation  points  price  \
# variety
# White Blend                      Vulkà Bianco      87    NaN
# Portuguese Red                       Avidagos      87   15.0
# ...                                       ...     ...    ...
# Pinot Gris                                NaN      90   32.0
# Gewürztraminer  Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                          province region_1 region_2    taster_name  \
# variety
# White Blend     Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# Portuguese Red              Douro      NaN      NaN     Roger Voss
# ...                           ...      ...      ...            ...
# Pinot Gris                 Alsace   Alsace      NaN     Roger Voss
# Gewürztraminer             Alsace   Alsace      NaN     Roger Voss
#
#                taster_twitter_handle  \
# variety
# White Blend             @kerinokeefe
# Portuguese Red            @vossroger
# ...                              ...
# Pinot Gris                @vossroger
# Gewürztraminer            @vossroger
#
#                                                             title  \
# variety
# White Blend                     Nicosia 2013 Vulkà Bianco  (Etna)
# Portuguese Red      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                           ...
# Pinot Gris          Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# Gewürztraminer  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                               winery
# variety
# White Blend                  Nicosia
# Portuguese Red   Quinta dos Avidagos
# ...                              ...
# Pinot Gris      Domaine Marcel Deiss
# Gewürztraminer      Domaine Schoffit
#
# [129971 rows x 12 columns]

# %%
winemag.country == 'Germany'
# Out:
# id
# 0         False
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
winemag.loc[winemag.country == 'Germany']
# Out:
#         country                                        description  \
# id
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 15      Germany  Zesty orange peels and apple notes abound in t...
# ...         ...                                                ...
# 129946  Germany  Plump, clingy peach and honey notes are cut wi...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                    designation  points  price     province  \
# id
# 8                                        Shine      87   12.0  Rheinhessen
# 15                                       Devon      87   24.0        Mosel
# ...                                        ...     ...    ...          ...
# 129946                                     Dom      90   17.0        Mosel
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0        Mosel
#
#        region_1 region_2         taster_name taster_twitter_handle  \
# id
# 8           NaN      NaN  Anna Lee C. Iijima                   NaN
# 15          NaN      NaN  Anna Lee C. Iijima                   NaN
# ...         ...      ...                 ...                   ...
# 129946      NaN      NaN  Anna Lee C. Iijima                   NaN
# 129966      NaN      NaN  Anna Lee C. Iijima                   NaN
#
#                                                     title         variety  \
# id
# 8       Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...  Gewürztraminer
# 15            Richard Böcking 2013 Devon Riesling (Mosel)        Riesling
# ...                                                   ...             ...
# 129946  Bischöfliche Weingüter Trier 2013 Dom Riesling...        Riesling
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
#
#                                           winery
# id
# 8                                    Heinz Eifel
# 15                               Richard Böcking
# ...                                          ...
# 129946              Bischöfliche Weingüter Trier
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
#
# [2165 rows x 13 columns]

# %%
winemag.loc[(winemag.country == 'Germany') & (winemag.designation == 'Shine')]
# Out:
#         country                                        description  \
# id
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 8365    Germany  Plush and plump, this is an easygoing off-dry ...
# ...         ...                                                ...
# 59003   Germany  Slicks of preserved peach and apple marmalade ...
# 114337  Germany  While muted on the nose, this refreshing off-d...
#
#        designation  points  price     province region_1 region_2  \
# id
# 8            Shine      87   12.0  Rheinhessen      NaN      NaN
# 8365         Shine      87   10.0  Rheinhessen      NaN      NaN
# ...            ...     ...    ...          ...      ...      ...
# 59003        Shine      88   10.0  Rheinhessen      NaN      NaN
# 114337       Shine      88   10.0  Rheinhessen      NaN      NaN
#
#                taster_name taster_twitter_handle  \
# id
# 8       Anna Lee C. Iijima                   NaN
# 8365    Anna Lee C. Iijima                   NaN
# ...                    ...                   ...
# 59003   Anna Lee C. Iijima                   NaN
# 114337  Anna Lee C. Iijima                   NaN
#
#                                                     title         variety  \
# id
# 8       Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...  Gewürztraminer
# 8365        Heinz Eifel 2015 Shine Riesling (Rheinhessen)        Riesling
# ...                                                   ...             ...
# 59003       Heinz Eifel 2014 Shine Riesling (Rheinhessen)        Riesling
# 114337      Heinz Eifel 2016 Shine Riesling (Rheinhessen)        Riesling
#
#              winery
# id
# 8       Heinz Eifel
# 8365    Heinz Eifel
# ...             ...
# 59003   Heinz Eifel
# 114337  Heinz Eifel
#
# [6 rows x 13 columns]

# %%
winemag.loc[winemag.country.isin(['Italy', 'Germany'])]
# Out:
#         country                                        description  \
# id
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 6         Italy  Here's a bright, informal red that opens with ...
# ...         ...                                                ...
# 129962    Italy  Blackberry, cassis, grilled herb and toasted a...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                    designation  points  price  \
# id
# 0                                 Vulkà Bianco      87    NaN
# 6                                      Belsito      87   16.0
# ...                                        ...     ...    ...
# 129962               Sàgana Tenuta San Giacomo      90   40.0
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
#
#                  province  region_1 region_2         taster_name  \
# id
# 0       Sicily & Sardinia      Etna      NaN       Kerin O’Keefe
# 6       Sicily & Sardinia  Vittoria      NaN       Kerin O’Keefe
# ...                   ...       ...      ...                 ...
# 129962  Sicily & Sardinia   Sicilia      NaN       Kerin O’Keefe
# 129966              Mosel       NaN      NaN  Anna Lee C. Iijima
#
#        taster_twitter_handle  \
# id
# 0               @kerinokeefe
# 6               @kerinokeefe
# ...                      ...
# 129962          @kerinokeefe
# 129966                   NaN
#
#                                                     title       variety  \
# id
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)   White Blend
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# ...                                                   ...           ...
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...  Nero d'Avola
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...      Riesling
#
#                                           winery
# id
# 0                                        Nicosia
# 6                                Terre di Giurfo
# ...                                          ...
# 129962                                  Cusumano
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
#
# [21705 rows x 13 columns]

# %%
winemag.loc[(winemag.price.notnull()) & (winemag.country == 'Italy')]
# Out:
#        country                                        description  \
# id
# 6        Italy  Here's a bright, informal red that opens with ...
# 22       Italy  Delicate aromas recall white flower and citrus...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# id
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# 22                      Ficiligno      87   19.0  Sicily & Sardinia   Sicilia
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# id
# 6           NaN  Kerin O’Keefe          @kerinokeefe
# 22          NaN  Kerin O’Keefe          @kerinokeefe
# ...         ...            ...                   ...
# 129961      NaN  Kerin O’Keefe          @kerinokeefe
# 129962      NaN  Kerin O’Keefe          @kerinokeefe
#
#                                                     title       variety  \
# id
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# 22      Baglio di Pianetto 2007 Ficiligno White (Sicilia)   White Blend
# ...                                                   ...           ...
# 129961                        COS 2013 Frappato (Sicilia)      Frappato
# 129962  Cusumano 2012 Sàgana Tenuta San Giacomo Nero d...  Nero d'Avola
#
#                     winery
# id
# 6          Terre di Giurfo
# 22      Baglio di Pianetto
# ...                    ...
# 129961                 COS
# 129962            Cusumano
#
# [16914 rows x 13 columns]

# %%
winemag['index_backwards'] = range(len(winemag), 0, -1)
winemag['index_backwards']
# Out:
# id
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64
